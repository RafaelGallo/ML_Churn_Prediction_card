# %% [markdown]
# # <div style="color:green;display:fill;border-radius:5px;background-color:#9DCDD1;font-family:Nexa;overflow:hidden"><p style="padding:20px;color:black;overflow:hidden;font-size:100%;letter-spacing:0.5px;margin:0"><b></b>Análise dados - Churn Card</p></div>
#
# ![](https://img.freepik.com/vetores-gratis/conceito-de-protecao-dos-direitos-do-consumidor-a-definicao-de-direito-do-consumidor-e-o-direito-de-ter-informacoes-sobre-a-qualidade-potencia-quantidade-pureza-preco-e-padrao-de-bens-ou-servicos-vector-flat_1150-60891.jpg?t=st=1714415761~exp=1714419361~hmac=978b421119034f56dd06c8a15931eb21afffed3b5a57c9b1b2e5bd2758e97b28&w=1480)
#
# # Problema négocio - Churn Card
#
# Em um ambiente altamente competitivo no setor de cartões de crédito, a retenção de clientes emerge como um fator crítico para a sustentabilidade e o crescimento contínuo das empresas. O churn, ou seja, a taxa de clientes que optam por cancelar seus cartões, representa não apenas uma perda financeira direta, mas também um indicativo de insatisfação ou desengajamento com os serviços oferecidos. Portanto, compreender e antecipar o churn torna-se essencial para mitigar seus impactos negativos e promover o sucesso a longo prazo.
#
# O churn de clientes é um desafio multifacetado que pode afetar diretamente a lucratividade, a participação de mercado e a reputação de uma empresa. Além dos custos associados à aquisição de novos clientes, a perda de clientes existentes pode resultar em uma diminuição da receita recorrente e na necessidade de investimentos adicionais em marketing e vendas para compensar essas perdas. Além disso, um alto índice de churn pode minar a confiança dos investidores e afetar negativamente a avaliação da empresa no mercado financeiro.
#
# Nesse contexto, a capacidade de prever com precisão quais clientes têm maior probabilidade de cancelar seus cartões de crédito torna-se uma vantagem estratégica significativa. A análise de dados desempenha um papel fundamental nesse processo, permitindo que as empresas identifiquem padrões e tendências comportamentais que precedem o cancelamento. Modelos preditivos sofisticados podem ser desenvolvidos para avaliar uma variedade de variáveis, incluindo histórico de transações, padrões de uso, interações com o serviço de atendimento ao cliente e até mesmo dados demográficos e psicográficos.
#
# Antecipar o churn não se limita apenas à identificação dos clientes em risco, mas também envolve a implementação de estratégias eficazes de retenção. Isso inclui a personalização da comunicação e das ofertas para atender às necessidades específicas de cada cliente, o desenvolvimento de programas de fidelidade e recompensas, e o aprimoramento contínuo da experiência do usuário. Além disso, as empresas podem adotar abordagens proativas, como entrar em contato com os clientes antes que eles expressem sua intenção de cancelar, oferecendo soluções alternativas ou vantagens adicionais para incentivá-los a permanecer.
#
# Ao adotar uma abordagem abrangente para gerenciar o churn, as empresas podem não apenas reduzir suas taxas de cancelamento, mas também fortalecer os laços com os clientes existentes e aumentar sua lealdade à marca. Isso não apenas impulsionará a rentabilidade a curto prazo, mas também estabelecerá uma base sólida para o crescimento sustentável no futuro. Em última análise, a capacidade de entender e antecipar as necessidades e preferências dos clientes será um diferencial competitivo crucial em um mercado cada vez mais dinâmico e etempo.ente.

# %% [markdown]
# ## Objetivos análise dados
#
# Os objetivos da análise de dados são multifacetados e fundamentais para a compreensão e melhoria dos processos de negócios. No contexto específico de análise de churn, o objetivo principal é descobrir insights que possam ajudar a entender melhor as razões por trás do churn dos clientes e, assim, desenvolver estratégias eficazes de retenção. Para alcançar esse objetivo, o processo de análise de dados envolve várias etapas. Primeiramente, é essencial coletar e integrar dados relevantes de diversas fontes, como transações de clientes, interações de atendimento ao cliente, feedback dos clientes e informações demográficas. Esses dados formam a base para toda a análise subsequente.
#
# Em seguida, é necessário realizar uma exploração e análise detalhada dos dados, utilizando técnicas estatísticas e de visualização para identificar padrões, tendências e correlações significativas. Isso pode envolver a utilização de gráficos, tabelas de frequência, análise de correlação e outras técnicas exploratórias de dados. Uma vez identificados os padrões relevantes, o próximo passo é realizar análises mais avançadas para extrair insights mais profundos. Isso pode incluir a aplicação de técnicas de modelagem preditiva, como regressão logística, árvores de decisão ou redes neurais, para prever o churn com base nos dados disponíveis. Além disso, técnicas de segmentação de clientes, como clustering ou análise de RFM (Recência, Frequência, Valor Monetário), podem ser usadas para identificar diferentes perfis de clientes e entender suas características distintas.
#
# Por fim, os insights obtidos por meio da análise de dados podem ser traduzidos em ações concretas para reduzir o churn. Isso pode incluir o desenvolvimento de programas de fidelidade personalizados, melhorias nos produtos ou serviços, ajustes na estratégia de marketing ou até mesmo intervenções direcionadas para clientes em risco iminente de churn.
#
# Em resumo, os objetivos da análise de dados no contexto do churn são encontrar insights acionáveis que possam informar e orientar as estratégias de retenção de clientes. Ao compreender melhor os padrões e comportamentos dos clientes, as empresas podem tomar decisões mais informadas e eficazes para manter a satisfação do cliente e maximizar o valor do cliente ao longo do tempo.

# %%
# Bibliotecas sistema
import re
import os
import unicodedata
import itertools

# Biblioteca para manipulação de arquivos
import pandas as pd
import numpy as np 
import pandas

# Visualização de dados
import plotly
import seaborn as sns
import matplotlib.pylab as pl
import matplotlib as m
import matplotlib as mpl
import matplotlib.pyplot as plt
import plotly.express as px
from matplotlib import pyplot as plt
from IPython.display import SVG

# Configuração para os gráficos largura e layout dos graficos
sns.set_theme(style='whitegrid')
palette='viridis'

# Warnings retirar alertas 
import warnings
warnings.filterwarnings("ignore")

# Versão do python
from platform import python_version
print('Versão python neste Jupyter Notebook:', python_version())

# Carregar as versões das bibliotecas
import watermark

# Versões das bibliotecas
# %reload_ext watermark
# %watermark -a "Versões das bibliotecas" --iversions
# Out:
# Versão python neste Jupyter Notebook: 3.11.5
# Author: Versões das bibliotecas
#
# seaborn   : 0.12.2
# numpy     : 1.24.3
# watermark : 2.4.3
# re        : 2.2.1
# plotly    : 5.9.0
# pandas    : 1.5.3
# matplotlib: 3.7.1

# %% [markdown]
# # <div style="color:green;display:fill;border-radius:5px;background-color:#9DCDD1;font-family:Nexa;overflow:hidden"><p style="padding:20px;color:black;overflow:hidden;font-size:100%;letter-spacing:0.5px;margin:0"><b>1.</b>Base dados</p></div>
#
# - **CLIENTNUM:** Número de identificação único para cada cliente.
# - **Attrition_Flag:** Indica se o cliente cancelou o cartão de crédito (churn). Pode ter valores como "Existing Customer" (Cliente Existente) ou "Attrited Customer" (Cliente Cancelado).
# - **Customer_Age:** Idade do cliente.
# - **Gender:** Gênero do cliente.
# - **Dependent_count:** Número de dependentes do cliente.
# - **Education_Level:** Nível de educação do cliente.
# - **Marital_Status:** Estado civil do cliente.
# - **Income_Category:** Categoria de renda do cliente.
# - **Card_Category:** Categoria do cartão de crédito (por exemplo, "Blue", "Silver", "Gold", "Platinum").
# - **Months_on_book:** Número de meses desde que o cliente abriu a conta.
# - **Total_Relationship_Count:** Número total de produtos bancários que o cliente possui.
# - **Months_Inactive_12_mon:** Número de meses em que o cliente esteve inativo nos últimos 12 meses.
# - **Contacts_Count_12_mon:** Número de contatos que o cliente teve com a instituição nos últimos 12 meses.
# - **Credit_Limit:** Limite de crédito do cliente.
# - **Total_Revolving_Bal:** Saldo total de crédito rotativo do cliente.
# - **Avg_Open_To_Buy:** Média do valor disponível para compra.
# - **Total_Amt_Chng_Q4_Q1:** Mudança percentual no valor da transação do último trimestre para o primeiro trimestre.
# - **Total_Trans_Amt:** Valor total das transações feitas pelo cliente.
# - **Total_Trans_Ct:** Total de transações feitas pelo cliente.
# - **Total_Ct_Chng_Q4_Q1:** Mudança percentual no número de transações do último trimestre para o primeiro trimestre.
# - **Avg_Utilization_Ratio:** Razão média de utilização do crédito.
# - **Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1:** Valor derivado do modelo de Naive Bayes para prever o churn (não utilizado para análise).
# - **Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2:** Outro valor derivado do modelo de Naive Bayes para prever o churn (não utilizado para análise).

# %%
# Base dados

# Definir opções do Pandas para exibir todas as colunas e linhas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Base dados
data = pd.read_csv("credit_card_churn.csv")
data.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0              39                         5                       1
# ...

# %%
# Visualizando 5 primeiros dados
data.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# 0              39                         5                       1
# ...

# %%
# Visualizando 5 últimos dados
data.tail()
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# ...

# %%
# Linhas e colunas
data.shape
# Out:
# (10127, 23)

# %%
# Info dados
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                                                                                                                              Non-Null Count  Dtype
# ---  ------                                                                                                                              --------------  -----
#  0   CLIENTNUM                                                                                                                           10127 non-null  int64
#  1   Attrition_Flag                                                                                                                      10127 non-null  object
#  2   Customer_Age                                                                                                                        10127 non-null  int64
# ...

# %%
# Tipo dados
data.dtypes
# Out:
# CLIENTNUM                                                                                                                               int64
# Attrition_Flag                                                                                                                         object
# Customer_Age                                                                                                                            int64
# Gender                                                                                                                                 object
# Dependent_count                                                                                                                         int64
# Education_Level                                                                                                                        object
# ...

# %% [markdown]
# # <div style="color:green;display:fill;border-radius:5px;background-color:#9DCDD1;font-family:Nexa;overflow:hidden"><p style="padding:20px;color:black;overflow:hidden;font-size:100%;letter-spacing:0.5px;margin:0"><b>2. </b>Análise dados</p></div>

# %%
# Criar um dicionário de mapeamento
mapping = {'Attrited Customer': "Não Churn", 
           'Existing Customer': "Churn"}

# Aplicar o mapeamento para converter a coluna em numérica
data['Attrition_Flag'] = data['Attrition_Flag'].replace(mapping)

# %%
# Distribuição de frequência da variável alvo
plt.figure(figsize=(8, 5))
sns.countplot(data, x='Attrition_Flag', palette='Set2')
plt.title('Distribuição da Variável Alvo')
plt.xlabel('Attrition Flag')
plt.ylabel('Frequência')
plt.grid(False)
plt.show()

# %% [markdown]
# **Análise:** Aqui, essa variável representa as colunas, como churn e não churn, que são essenciais como atributos para treinar um modelo de machine learning. A coluna alvo, neste contexto, refere-se à variável que o modelo tentará prever ou classificar, como churn, que é crucial para a análise e previsão de comportamento de clientes.

# %%
# Relação entre gênero e churn
plt.figure(figsize=(10, 8))
sns.countplot(data, x='Gender', hue=data['Attrition_Flag'], palette='Set2')
plt.title('Relação entre Gênero e Churn')
plt.xlabel('Gênero')
plt.ylabel('Frequência')
plt.grid(False)
plt.show()

# %% [markdown]
# **Análise**: Esta variável descreve os gêneros masculino e feminino, fornecendo insights sobre a distribuição do churn entre ambos os grupos de gênero. Essa análise permite uma compreensão mais abrangente dos padrões de comportamento e preferências, fundamentais para estratégias de retenção e segmentação de clientes.

# %%
# Describe geral
data.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %% [markdown]
# **Análise:** Através da função **describe()** do pandas, é possível obter uma visão abrangente dos dados, incluindo estatísticas como média, soma e desvio padrão. Essa funcionalidade oferece uma análise estatística fundamental para compreender a distribuição, tendências e variabilidade dos dados, sendo uma ferramenta indispensável para a exploração e entendimento dos conjuntos de dados

# %%
# Análise de Correlação

# Variaveis para correlação
data_corr = data[["Attrition_Flag", "Customer_Age", "Gender", "Dependent_count", "Education_Level", "Marital_Status", "Income_Category", "Card_Category", "Months_on_book", "Total_Relationship_Count", "Months_Inactive_12_mon", "Contacts_Count_12_mon", "Credit_Limit", "Total_Revolving_Bal","Avg_Open_To_Buy", "Total_Amt_Chng_Q4_Q1", "Total_Trans_Amt", "Total_Trans_Ct", "Total_Ct_Chng_Q4_Q1", "Avg_Utilization_Ratio"]]

# Plot correlation matrix
correlation_matrix = data_corr.corr()
plt.figure(figsize=(20.5, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Matriz de Correlação')
plt.show()

# %% [markdown]
# O total de transações, o saldo rotativo total e a mudança total no número têm uma correlação negativa moderada com o alvo. Isso faz total sentido. Quanto menos transações um cliente faz, mais provável é que ele cancele. Além disso, clientes com saldos rotativos mais baixos e menos variação em seus números de transações são propensos a cancelar devido à inatividade.
#
# A idade do cliente e os meses de permanência no livro estão fortemente correlacionados positivamente. Quanto mais velho é um cliente, mais tempo ele passa consumindo os serviços de cartão de crédito do banco e vice-versa. Assim, a empresa deve concentrar seus esforços em manter os clientes antigos e leais e aumentar a permanência dos mais jovens. O limite de crédito e a taxa média de utilização estão moderadamente correlacionados negativamente. Quanto maior o limite de crédito do cliente, menor é a taxa média de utilização. O saldo rotativo total e a taxa média de utilização estão fortemente correlacionados positivamente. Isso faz sentido.
#
# À medida que um cliente usa mais seu cartão de crédito, ele terá que pagar saldos rotativos mais altos. Curiosamente, o gênero tem uma correlação positiva moderada com o limite de crédito. Isso pode indicar que os clientes do sexo masculino tendem a ter limites de crédito mais altos do que os do sexo feminino. Algumas características que estão naturalmente relacionadas são altamente correlacionadas, como esperado. Este é o caso do valor total da transação e do total de transações.
#
# Ao construir modelos lineares, devemos nos preocupar com problemas de multicolinearidade, que ocorrem quando duas ou mais variáveis independentes estão altamente correlacionadas. Embora seja diagnosticado com o fator de inflação da variância, observar a correlação de Pearson entre pares pode nos indicar esse problema. Este é o caso aqui. No entanto, uma vez que vou me concentrar no poder preditivo, usando algoritmos mais robustos como o LightGBM, não me preocuparei com isso agora. Curiosamente, o valor médio aberto para comprar e o limite de crédito estão perfeitamente correlacionados positivamente.
#
# Isso significa que essas duas variáveis têm um relacionamento linear forte e consistente na mesma direção. Isso faz sentido, já que "aberto para comprar" significa o valor restante em seu cartão de crédito para usar e o limite significa o valor usado que ainda não foi pago. Como apresentam essa correlação perfeita, uma delas se torna redundante. Assim, vou descartar o "avg_open_to_buy" na etapa de modelagem porque o "credit_limit" é mais informativo.

# %%
fig, axes = plt.subplots(1, 6, figsize=(30, 5))

sns.scatterplot(data=data, x='Customer_Age', y='Months_on_book', hue='Attrition_Flag', ax=axes[0], palette='Set2')
sns.scatterplot(data=data, x='Avg_Open_To_Buy', y='Total_Revolving_Bal',  hue='Attrition_Flag', ax=axes[1], palette='Set2')
sns.scatterplot(data=data, x='Total_Revolving_Bal', y='Avg_Utilization_Ratio',  hue='Attrition_Flag', ax=axes[2], palette='Set2')
sns.scatterplot(data=data, x='Total_Revolving_Bal', y='Months_on_book',  hue='Attrition_Flag', ax=axes[3], palette='Set2')
sns.scatterplot(data=data, x='Total_Amt_Chng_Q4_Q1', y='Total_Ct_Chng_Q4_Q1',  hue='Attrition_Flag', ax=axes[4], palette='Set2')
sns.scatterplot(data=data, x='Credit_Limit', y='Avg_Utilization_Ratio',  hue='Attrition_Flag', ax=axes[5], palette='Set2')
plt.grid(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# Curiosamente, o limite de crédito e a taxa média de utilização apresentam uma relação de decrescimento exponencial! Isso indica que, à medida que o limite de crédito aumenta, a taxa média de utilização diminui em uma taxa exponencial.
#
# Portanto, clientes com limites de crédito mais altos usam seus cartões de crédito menos frequentemente. Essa dinâmica sugere que existe uma relação não linear entre o limite de crédito e o uso do cartão, com uma diminuição mais acentuada na taxa de utilização à medida que o limite de crédito aumenta. Isso pode ser um insight valioso para o banco entender os padrões de gastos de seus clientes e ajustar suas estratégias de gerenciamento de crédito e retenção de clientes.

# %%
# Análise de Correlação Específica
# Correlação entre Total_Trans_Amt e Total_Trans_Ct
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Total_Trans_Amt', y='Total_Trans_Ct', data=data, hue='Attrition_Flag', palette='Set2')
plt.title('Relação entre Total de Transações')
plt.xlabel('Total de Transações')
plt.ylabel('Quantidade de Transações')
plt.grid(False)
plt.show()

# %% [markdown]
# **Análise:** Neste gráfico, é apresentada a relação entre o total de transações realizadas pelos clientes, permitindo visualizar a posição do churn em relação a essa métrica. Essa representação gráfica oferece insights valiosos sobre como o comportamento transacional dos clientes está relacionado ao churn, possibilitando a identificação de padrões e tendências que podem influenciar estratégias de retenção e engajamento.

# %%
# Análise Univariada Adicional
# Distribuição do limite de crédito por categoria de cartão
plt.figure(figsize=(20, 10)) 
sns.boxplot(x='Credit_Limit', y='Card_Category', data=data, hue='Attrition_Flag', palette='Set2')
plt.title('Distribuição do Limite de Crédito por Categoria de Cartão')
plt.xlabel('Categoria de Cartão')
plt.ylabel('Limite de Crédito')
plt.grid(False)
plt.show()

# %% [markdown]
# **Análise:** Neste gráfico, é analisado o limite do cartão por bandeira de cartão de crédito. No primeiro grupo de bandeiras, observamos que a categoria Blue apresenta uma alta incidência de outliers, o que pode indicar situações de churn ou até mesmo casos de fraude de cartão de crédito. Essa análise sugere a necessidade de uma investigação mais aprofundada sobre os padrões de utilização e comportamento dos clientes associados a essa categoria, visando implementar medidas de mitigação de riscos e melhorias na segurança das transações.

# %%
# Distribuição do Churn em relação ao Total de Transações
plt.figure(figsize=(12, 8))
sns.histplot(data=data, x='Total_Trans_Amt', hue='Attrition_Flag', kde=True, palette='Set2')
plt.title('Distribuição do Churn em relação ao Total de Transações')
plt.xlabel('Total de Transações')
plt.ylabel('Frequência')
plt.grid(False)
plt.show()

# %% [markdown]
# **Análise**: Neste gráfico, são destacadas as transações de churn, totalizando 5000 casos registrados de churn no cartão de crédito. Essa análise revela a magnitude do churn no contexto das transações financeiras, fornecendo insights valiosos sobre a frequência e o impacto dessas ocorrências. Além disso, sugere a necessidade de estratégias direcionadas para retenção de clientes e mitigação do churn, visando a estabilidade e o crescimento sustentável do negócio.

# %%
# Distribuição do Churn em relação ao Saldo Rotativo Total
plt.figure(figsize=(12,8))
sns.histplot(data=data, x='Total_Revolving_Bal', hue='Attrition_Flag', kde=True, palette='Set2')
plt.title('Distribuição do Churn em relação ao Saldo Rotativo Total')
plt.xlabel('Saldo Rotativo Total')
plt.ylabel('Frequência')
plt.grid(False)
plt.show()

# %% [markdown]
# **Análise:** Neste gráfico, é apresentada a distribuição do churn com base no saldo rotativo. Observa-se que a maioria dos casos de churn ocorre em saldos rotativos variando de 500 a 2500 unidades monetárias. Essa análise destaca a relação entre o saldo rotativo e a ocorrência de churn, indicando áreas de potencial preocupação ou oportunidade para intervenção. Além disso, sugere a importância de estratégias de gestão de crédito e engajamento de clientes para reduzir a incidência de churn e promover a fidelização.

# %%
# 1. Taxa de Churn Mensal usando 'Months_on_book'
churn_monthly = data[data['Attrition_Flag'] == 'Attrited Customer'].groupby('Months_on_book').size() / data.groupby('Months_on_book').size()

# 2. Taxa de Churn Anual
churn_annual = data[data['Attrition_Flag'] == 'Attrited Customer'].groupby('Months_on_book').size() / data.groupby('Months_on_book').size()

# 3. Taxa de Retenção Mensal
retention_monthly = 1 - churn_monthly

# 4. Taxa de Retenção Anual
retention_annual = 1 - churn_annual

# 5. Valor Médio de Transação por Cliente
average_transaction_per_customer = data.groupby('CLIENTNUM')['Total_Trans_Amt'].mean()

# 6. Saldo Médio Rotativo por Cliente
average_rev_bal_per_customer = data.groupby('CLIENTNUM')['Total_Revolving_Bal'].mean()

# 7. Número Médio de Transações por Cliente
average_transactions_per_customer = data.groupby('CLIENTNUM')['Total_Trans_Ct'].mean()

# 8. Taxa de Utilização do Limite de Crédito
credit_utilization_rate = (data['Total_Revolving_Bal'] / data['Credit_Limit']) * 100

# 9. Taxa de Ativação
# Vamos supor que 'Months_Inactive_12_mon' seja 0 para indicar clientes ativos
activation_rate = (data['Months_Inactive_12_mon'] == 0).sum() / len(data)

# %%
# 5. Valor Médio de Transação por Cliente
plt.figure(figsize=(12.5, 5))
average_transaction_per_customer.hist(bins=30, color='green')
plt.title('Histograma do Valor Médio de Transação por Cliente')
plt.xlabel('Valor Médio de Transação')
plt.ylabel('Frequência')
plt.tight_layout()
plt.grid(False)
plt.show()

# %% [markdown]
# Neste gráfico, podemos observar a média de transações de vendas realizadas pelos clientes, distinguindo entre pagamentos feitos com cartão de crédito e boleto bancário. Nota-se que, em média, os clientes realizam cerca de 2000 transações de vendas, sendo uma parte desse total efetuada com cartão de crédito e outra por meio de boleto bancário. Esta análise permite entender melhor os padrões de pagamento dos clientes e a preferência por diferentes métodos de pagamento. Além disso, fornece insights sobre a dinâmica de consumo e pode orientar estratégias de marketing e operacionais voltadas para otimização da experiência do cliente e aumento da eficiência nas transações.

# %%
# 7. Número Médio de Transações por Cliente
plt.figure(figsize=(12.5, 6))
average_transactions_per_customer.hist(bins=30, color='green')
plt.title('Histograma do Número Médio de Transações por Cliente')
plt.xlabel('Número Médio de Transações')
plt.ylabel('Frequência')
plt.tight_layout()
plt.grid(False)
plt.show()

# %% [markdown]
# O histograma do número médio de transações por cliente é uma representação visual que mostra a distribuição da quantidade média de transações realizadas por cada cliente em um determinado período de tempo. Este gráfico é construído dividindo o número total de transações pelo número de clientes e agrupando esses valores em intervalos específicos. Ao analisar esse histograma, é possível identificar padrões de comportamento de compra dos clientes. Por exemplo, pode-se observar se a maioria dos clientes realiza um baixo número de transações, indicando uma base de clientes mais esporádica, ou se há um grupo de clientes que realizam um grande número de transações, sugerindo uma base mais engajada e fiel.
#
# Além disso, o histograma pode revelar insights sobre a segmentação de clientes e oportunidades de marketing. Por exemplo, se houver um pico em um determinado intervalo de transações, isso pode indicar um segmento de clientes com necessidades ou comportamentos específicos que podem ser explorados para campanhas direcionadas. Em resumo, o histograma do número médio de transações por cliente é uma ferramenta poderosa para entender a dinâmica de compra dos clientes e orientar estratégias de negócios voltadas para aprimorar a experiência do cliente e impulsionar o crescimento das vendas.

# %%
# 8. Taxa de Utilização do Limite de Crédito
plt.figure(figsize=(12.5, 6))
plt.hist(credit_utilization_rate, bins=30, color='green')
plt.title('Histograma da Taxa de Utilização do Limite de Crédito')
plt.xlabel('Taxa de Utilização (%)')
plt.ylabel('Frequência')
plt.tight_layout()
plt.grid(False)
plt.show()

# %% [markdown]
# O histograma da taxa de utilização do limite de crédito é uma representação gráfica que ilustra a distribuição da proporção entre o saldo atual de um cliente em relação ao seu limite de crédito disponível. Este gráfico é construído dividindo o saldo pelo limite de crédito e agrupando esses valores em intervalos específicos.
#
# Ao examinar esse histograma, é possível entender melhor como os clientes estão utilizando seu crédito disponível. Por exemplo, pode-se observar se a maioria dos clientes mantém uma baixa utilização do limite de crédito, o que pode indicar uma gestão financeira mais conservadora. Por outro lado, picos em intervalos de alta utilização podem sugerir um grupo de clientes que estão utilizando seu crédito de forma mais agressiva. Além disso, o histograma pode fornecer insights sobre o risco de crédito da carteira de clientes. Uma alta concentração de clientes com uma alta taxa de utilização do limite de crédito pode indicar uma maior probabilidade de inadimplência e pode sinalizar a necessidade de medidas proativas para mitigar esse risco. Em resumo, o histograma da taxa de utilização do limite de crédito é uma ferramenta valiosa para entender o comportamento financeiro dos clientes, identificar padrões de risco e orientar estratégias para gerenciamento de crédito e tomada de decisões financeiras.

# %%
# 9. Taxa de Ativação
plt.figure(figsize=(8, 6))
plt.bar(['Ativos', 'Inativos'], [activation_rate * 100, (1 - activation_rate) * 100], color=['red', 'green'])
plt.title('Taxa de Ativação')
plt.ylabel('Porcentagem')
plt.tight_layout()
plt.grid(False)
plt.show()

# %% [markdown]
# O gráfico de barras da taxa de ativação é uma representação visual que mostra a proporção de clientes que ativaram um determinado serviço, produto ou recurso em comparação com o total de clientes elegíveis. Cada barra no gráfico representa uma categoria específica ou período de tempo, e a altura da barra indica a taxa de ativação para essa categoria ou período. Ao analisar esse gráfico, é possível avaliar o desempenho da taxa de ativação ao longo do tempo ou entre diferentes grupos de clientes. Por exemplo, pode-se comparar a taxa de ativação entre diferentes regiões geográficas, faixas etárias ou segmentos de mercado para identificar padrões e tendências.
#
# Além disso, o gráfico de barras da taxa de ativação pode ser usado para avaliar a eficácia de campanhas de marketing, programas de fidelidade ou melhorias de produto. Se a taxa de ativação aumentar após o lançamento de uma nova campanha ou recurso, isso pode indicar um impacto positivo nas ações realizadas. Em resumo, o gráfico de barras da taxa de ativação é uma ferramenta útil para monitorar e avaliar o sucesso de iniciativas de engajamento de clientes e para identificar áreas de oportunidade para melhorar a adoção de produtos ou serviços.

# %%
# Visualização da Distribuição da Categoria de Renda
plt.figure(figsize=(12.5, 6))
sns.countplot(data=data, x='Income_Category', hue='Attrition_Flag', palette='Set2')
plt.xlabel('Categoria de Renda')
plt.ylabel('Contagem')
plt.xticks(rotation=45)
plt.legend(title='Distribuição da Categoria de Renda', loc='upper right', labels=['Cliente Ativo', 'Cliente Cancelado'])
plt.tight_layout()
plt.grid(False)
plt.show()

# %% [markdown]
# A distribuição da categoria de renda é uma representação que ilustra como a renda dos indivíduos está distribuída em diferentes categorias. Geralmente apresentado em forma de gráfico, este tipo de análise permite entender a composição da população com base em sua capacidade financeira.
#
# Ao examinar essa distribuição, é possível identificar os diferentes estratos sociais e econômicos presentes em uma determinada amostra. Por exemplo, pode-se observar se a maioria dos indivíduos se enquadra em categorias de baixa, média ou alta renda, e qual a proporção de cada grupo em relação ao total da população analisada. Essa análise é valiosa para entender a demografia de uma região, orientar políticas públicas e estratégias de negócios, além de ser fundamental para segmentar o mercado e direcionar campanhas de marketing de forma mais eficaz. A distribuição da categoria de renda fornece insights valiosos sobre o poder de compra e o padrão de consumo de uma determinada população, auxiliando na tomada de decisões estratégicas em diversos setores.
#
# **Análise:** Este gráfico, podemos observar que há 3.000 clientes com renda ativa que mantêm o cartão de crédito, indicando que não houve churn nesse grupo. No entanto, em outra barra, identificamos que 100 clientes cancelaram o cartão. Essa análise oferece insights importantes sobre a retenção de clientes e a saúde da base de usuários do cartão de crédito. Além disso, sugere a necessidade de investigar os motivos que levaram ao cancelamento e implementar estratégias para reduzir a taxa de churn, garantindo a satisfação e fidelização dos clientes.

# %%
# Visualização do Índice de Engajamento do Cliente com diferenciação por churn
plt.figure(figsize=(10.5, 6))
sns.histplot(data=data, x=data['Total_Trans_Ct'] + data['Contacts_Count_12_mon'], bins=20, kde=True, hue='Attrition_Flag', multiple='stack', palette='Set2')
plt.title('Distribuição do Índice de Engajamento do Cliente')
plt.xlabel('Número Total de Transações e Contatos com o Serviço ao Cliente')
plt.ylabel('Frequência')
plt.legend(title='Churn', loc='upper right', labels=['Cliente Ativo', 'Cliente Cancelado'])
plt.tight_layout()
plt.grid(False)
plt.show()

# %% [markdown]
# **Análise:** Neste gráfico, observamos o cancelamento de cartões de crédito, com destaque para a categoria "Platinum", que apresenta um número significativo de cancelamentos. Essa observação sugere que os clientes que possuem cartões "Platinum" estão mais propensos a cancelar seus cartões, indicando possíveis casos de churn. Essa análise ressalta a importância de entender os motivos por trás desses cancelamentos e de implementar medidas para melhorar a retenção de clientes nessa categoria específica. Além disso, enfatiza a necessidade de um acompanhamento proativo dos clientes "Platinum" para garantir sua satisfação e fidelidade, visando manter uma base de clientes estável e lucrativa.

# %%
# 5. Índice de Satisfação do Cliente (usando o número médio de transações)
customer_satisfaction_index = data['Total_Trans_Ct'].mean()

# Visualização do Índice de Satisfação do Cliente
plt.figure(figsize=(8, 6))
sns.histplot(data=data, x='Total_Trans_Ct', bins=20, kde=True,palette='Set2')
plt.title('Distribuição do Índice de Satisfação do Cliente (Número de Transações)')
plt.xlabel('Número de Transações')
plt.ylabel('Frequência')
plt.tight_layout()
plt.grid(False)
plt.show()

# %% [markdown]
# **Análise:** Neste gráfico, visualizamos o índice total de satisfação do cliente, que abrange um total de 1200 clientes. Observamos que, dentro dessa amostra, o menor índice de satisfação registrado é de 20. Essa análise permite uma avaliação abrangente do nível geral de satisfação dos clientes, fornecendo insights sobre áreas de melhoria e pontos de atenção. Além disso, destaca a importância de entender as necessidades e expectativas dos clientes e de implementar medidas para aprimorar sua experiência, visando aumentar a fidelidade e o engajamento.

# %%
# Criar o gráfico de barras
plt.figure(figsize=(28.5, 10))
sns.barplot(data=data, x='Customer_Age', y='Credit_Limit', hue='Attrition_Flag', ci=None, palette='Set2')

# Adicionar título e rótulos dos eixos
plt.title('Média do Limite de Crédito por Idade e Gênero')
plt.xlabel('Idade')
plt.ylabel('Limite de Crédito')

# Adicionar legenda
plt.legend(title='Ocorencia de churn', loc='upper right')

# Exibir o gráfico
plt.grid(False)
plt.show()

# %% [markdown]
# **Análise:** Neste gráfico, apresentamos a distribuição das idades dos clientes que cancelaram o cartão de crédito. Observamos uma variabilidade significativa nas idades dos clientes que optaram pelo cancelamento do serviço. Essa análise nos permite compreender melhor o perfil demográfico dos clientes que decidem cancelar seus cartões, fornecendo insights valiosos sobre possíveis padrões ou tendências. Além disso, sugere a importância de uma abordagem segmentada para a retenção de clientes, levando em consideração as diferentes faixas etárias e necessidades específicas de cada grupo, visando reduzir a taxa de churn e promover a fidelização.

# %% [markdown]
# **Indicadores**
#
# **1) Education_Level e Marital_Status:** Podemos calcular a taxa de churn para cada categoria de educação e estado civil para entender se há alguma relação entre essas variáveis e o churn.
#
#
# **2) Income_Category:** Podemos criar intervalos de renda e calcular a taxa de churn para cada intervalo de renda para avaliar como a renda dos clientes afeta o churn.
#
#
# **3) Card_Category:** Podemos calcular a taxa de churn para cada tipo de cartão de crédito para ver se clientes com diferentes tipos de cartão têm diferentes comportamentos de churn.
#
#
# **4) Credit_Limit:** Podemos explorar a distribuição do limite de crédito entre clientes que cancelaram e não cancelaram o cartão, e também calcular estatísticas resumidas, como média e desvio padrão, para cada grupo.

# %%
# 1. Taxa de churn por Education_Level
plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='Education_Level', hue='Attrition_Flag', palette='Set2')
plt.title('Taxa de Churn por Education_Level')
plt.xlabel('Education_Level')
plt.ylabel('Contagem')
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(False)
plt.show()

# %% [markdown]
# **Análise:** Neste gráfico, observamos os diferentes níveis de escolaridade dos clientes em relação ao limite de crédito. Notamos que os clientes que frequentam a faculdade têm um limite de crédito mais elevado em comparação com outros grupos. Este padrão sugere que estudantes universitários, incluindo até mesmo estagiários que estão no mercado de trabalho, têm acesso a limites de crédito mais substanciais, com um limite médio de R$ 2.000,00.
#
# Por outro lado, indivíduos que estão no ensino médio apresentam um limite de crédito médio de R$ 1.800,00. Este contraste pode ser atribuído à percepção de que os estudantes universitários têm uma capacidade de pagamento potencialmente maior devido a oportunidades de renda associadas a estágios ou trabalhos de meio período. Além disso, ressalta a importância de considerar fatores demográficos, como o nível de educação, ao desenvolver estratégias de concessão de crédito e segmentação de clientes, visando oferecer produtos e serviços financeiros adequados às necessidades e capacidades de cada grupo.

# %%
# 2. Taxa de churn por Marital_Status
plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='Marital_Status', hue='Attrition_Flag', palette='Set2')
plt.title('Taxa de Churn por Marital_Status')
plt.xlabel('Marital_Status')
plt.ylabel('Contagem')
plt.tight_layout()
plt.grid(False)
plt.show()

# %% [markdown]
# Neste gráfico, exploramos a relação entre o estado civil dos clientes e a incidência de churn. Observamos que entre os clientes casados, há uma proporção significativa de casos de churn, indicando uma tendência de cancelamento do cartão de crédito. Isso pode sugerir uma necessidade de investigação mais detalhada para entender os motivos por trás desses cancelamentos e implementar estratégias de retenção direcionadas a esse grupo específico.
#
# Por outro lado, notamos que entre os clientes divorciados, a incidência de churn é menor, sugerindo uma maior estabilidade nesse segmento. Essa descoberta pode ser explorada para identificar padrões de comportamento e preferências entre diferentes estados civis, orientando a personalização de ofertas e serviços para atender às necessidades específicas de cada grupo. Além disso, ressalta a importância de considerar fatores demográficos, como estado civil, ao desenvolver estratégias de gerenciamento de relacionamento com o cliente e medidas para reduzir a taxa de churn.

# %%
# 4. Taxa de churn por Card_Category
plt.figure(figsize=(8, 6))
sns.countplot(data=data, x='Card_Category', hue='Attrition_Flag', palette='Set2')
plt.title('Taxa de Churn por Categoria de cartão')
plt.xlabel('Card_Category')
plt.ylabel('Contagem')
plt.tight_layout()
plt.grid(False)
plt.show()

# %% [markdown]
# Neste gráfico, é apresentada a distribuição dos casos de churn em diferentes categorias de cartão de crédito. Observa-se que diversas categorias estão representadas, cada uma com sua respectiva incidência de churn. Um destaque notável é a categoria "Blue", que apresenta um maior número de casos de churn em comparação com outras categorias. Essa observação levanta questões sobre os fatores que podem estar contribuindo para essa tendência, como a qualidade do serviço oferecido, os benefícios associados ao cartão ou até mesmo a experiência geral do cliente. Além disso, sugere a necessidade de uma análise mais detalhada para identificar possíveis pontos de melhoria e implementar estratégias específicas para reduzir a taxa de churn nessa categoria. Essa abordagem orientada por dados é fundamental para garantir a satisfação do cliente e promover a fidelização em todas as categorias de cartão de crédito.

# %%
# 5. Distribuição de Credit_Limit por churn
plt.figure(figsize=(8, 6)) 

sns.boxplot(data=data, x='Credit_Limit', y='Attrition_Flag', hue='Attrition_Flag', palette='Set2')
plt.title('Distribuição de Credit_Limit por churn')
plt.xlabel('Attrition_Flag')
plt.ylabel('Credit_Limit')
plt.tight_layout()
plt.grid(False)
plt.show()

# %% [markdown]
# Neste indicador, exploramos a relação entre o limite de crédito e os casos de churn. Observamos que, em situações de churn, houve casos registrados de cancelamento mesmo entre clientes com um limite de crédito máximo de 20.000. Isso sugere que o simples fato de ter um limite de crédito mais elevado não é necessariamente um indicador de fidelidade do cliente. Pode haver outros fatores em jogo, como a qualidade do serviço, a experiência do cliente ou mudanças nas circunstâncias financeiras do cliente. Portanto, entender esses padrões é crucial para identificar áreas de melhoria e implementar estratégias eficazes de retenção de clientes, que considerem não apenas o valor do limite de crédito, mas também outros aspectos que influenciam a satisfação e a lealdade do cliente.

# %%
# Calcular estatísticas descritivas para o limite de crédito
credit_limit_stats = data['Credit_Limit'].describe()

# Mostrar as estatísticas
print("Estatísticas Descritivas para o Limite de Crédito:")
print(credit_limit_stats)
# Out:
# Estatísticas Descritivas para o Limite de Crédito:
# count    10127.000000
# mean      8631.953698
# std       9088.776650
# min       1438.300000
# 25%       2555.000000
# 50%       4549.000000
# 75%      11067.500000
# max      34516.000000
# Name: Credit_Limit, dtype: float64

# %%
# Calcular a proporção de clientes com limite de crédito acima de um determinado valor
credit_limit_threshold = 10000
above_threshold = (data['Credit_Limit'] > credit_limit_threshold).sum()

# Mostrar a proporção
print(f"\nProporção de Clientes com Limite de Crédito ácima de {credit_limit_threshold}: {above_threshold:.2%}")
# Out:
# Proporção de Clientes com Limite de Crédito ácima de 10000: 275400.00%

# %% [markdown]
# Neste indicador, examinamos a proporção de clientes com limite de crédito acima de um determinado valor em relação aos casos de churn. Observamos que, mesmo entre os clientes com um limite de crédito mais elevado, acima de um determinado valor, houve casos de churn. Isso sugere que a mera posse de um limite de crédito mais generoso não garante necessariamente a fidelidade do cliente. Outros fatores, como a qualidade do serviço, a experiência do cliente e mudanças nas circunstâncias financeiras, também desempenham um papel crucial na retenção do cliente. Portanto, é essencial uma compreensão abrangente desses padrões para identificar áreas de melhoria e implementar estratégias eficazes de retenção de clientes, levando em consideração não apenas o valor absoluto do limite de crédito, mas também outros fatores que influenciam a satisfação e a lealdade do cliente.

# %%
from matplotlib.patches import Patch

# Definir cores para churn e não churn
colors = {'Existing Customer': 'green', 
          'Attrited Customer': 'red'}

# Definir o tamanho do gráfico
plt.figure(figsize=(10, 6))

# Plotar o histograma do limite de crédito
sns.histplot(data=data, x='Credit_Limit', bins=30, kde=True, hue='Attrition_Flag', palette='Set2')

# Adicionar título e rótulos dos eixos
plt.title('Distribuição do Limite de Crédito com Indicação de Churn')
plt.xlabel('Limite de Crédito')
plt.ylabel('Contagem')

# Criar manualmente as entradas da legenda
legend_elements = [Patch(facecolor=color, edgecolor='w', label=label) for label, color in colors.items()]

# Adicionar legenda
plt.legend(title='Distribuição do limite de crédito', loc='upper right', labels=['Cliente Ativo', 'Cliente Cancelado'])

# Exibir o gráfico
plt.tight_layout()
plt.grid(False)
plt.show()

# %% [markdown]
# **Análise:** Neste indicador, estamos analisando os casos relacionados ao limite de crédito dos cartões. Podemos observar que clientes com limites de até 1000 estão cancelando o cartão, o que reflete casos de churn. Além disso, podemos notar a presença de uma linha vermelha, que representa os clientes ativos com limite de crédito de até 30.000. Isso sugere uma variedade de cenários possíveis, onde diferentes fatores podem influenciar a decisão de pagar ou cancelar o cartão de crédito. Por exemplo, o pagamento do cartão pode ser influenciado por fatores como o salário mensal, os gastos regulares e as despesas familiares.
#
# É interessante notar que casais podem ter um limite de cartão mais alto do que uma pessoa solteira, refletindo diferentes estruturas de renda e necessidades de gastos. Portanto, entender essas nuances é fundamental para personalizar estratégias de retenção de clientes e promover a fidelidade dos clientes, considerando não apenas o limite de crédito, mas também outros fatores contextuais que impactam o comportamento do cliente

# %% [markdown]
# # Conclusão
#
# Nesta análise de churn, destacamos diversos insights relevantes que desempenham um papel fundamental na retenção de clientes. Evidenciamos que o limite do cartão de crédito emerge como um fator significativo, sugerindo uma possível correlação entre certos limites e a propensão dos clientes a cancelarem seus cartões. Além disso, a análise ressalta a importância do nível educacional dos clientes, assim como o tipo e categorias dos cartões de crédito que possuem, e também a faixa etária dos titulares de cartões ativos.
# Salientamos ainda que variáveis como salário e profissão exercem uma influência substancial no churn, evidenciando o impacto crucial da estabilidade financeira e da natureza ocupacional na decisão do cliente em manter ou cancelar o cartão de crédito.
#
# Diante da complexidade desses fatores, ressaltamos a necessidade de uma abordagem holística na retenção de clientes. Compreender essas nuances possibilita o desenvolvimento de estratégias mais eficazes e personalizadas, voltadas para atender às necessidades específicas de cada segmento de clientes. O objetivo é maximizar não apenas a fidelização, mas também o valor agregado por cada cliente à instituição.
